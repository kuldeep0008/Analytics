# %%
import pandas as pd
import numpy as np
Train_loan_df = pd.read_csv(r"C:\Users\kpanwar\Desktop\Loan_DataSet\Train.csv")

# %%
Train_loan_df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 5    LP001011    Male     Yes          2      Graduate           Yes
# 6    LP001013    Male     Yes          0  Not Graduate            No
# 7    LP001014    Male     Yes         3+      Graduate            No
# 8    LP001018    Male     Yes          2      Graduate            No
# 9    LP001020    Male     Yes          1      Graduate            No
# 10   LP001024    Male     Yes          2      Graduate            No
# 11   LP001027    Male     Yes          2      Graduate           NaN
# 12   LP001028    Male     Yes          2      Graduate            No
# ...

# %%
Train_loan_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
# Loan_ID              614 non-null object
# Gender               601 non-null object
# Married              611 non-null object
# Dependents           599 non-null object
# Education            614 non-null object
# Self_Employed        582 non-null object
# ApplicantIncome      614 non-null int64
# CoapplicantIncome    614 non-null float64
# LoanAmount           592 non-null float64
# Loan_Amount_Term     600 non-null float64
# Credit_History       564 non-null float64
# Property_Area        614 non-null object
# Loan_Status          614 non-null object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.4+ KB

# %%
Train_loan_df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
Train_loan_df.dropna(inplace= True)

# %%
Train_loan_df.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
Train_loan_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 480 entries, 1 to 613
# Data columns (total 13 columns):
# Loan_ID              480 non-null object
# Gender               480 non-null object
# Married              480 non-null object
# Dependents           480 non-null object
# Education            480 non-null object
# Self_Employed        480 non-null object
# ApplicantIncome      480 non-null int64
# CoapplicantIncome    480 non-null float64
# LoanAmount           480 non-null float64
# Loan_Amount_Term     480 non-null float64
# Credit_History       480 non-null float64
# Property_Area        480 non-null object
# Loan_Status          480 non-null object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 52.5+ KB

# %%
Train_loan_df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 5    LP001011    Male     Yes          2      Graduate           Yes
# 6    LP001013    Male     Yes          0  Not Graduate            No
# 7    LP001014    Male     Yes         3+      Graduate            No
# 8    LP001018    Male     Yes          2      Graduate            No
# 9    LP001020    Male     Yes          1      Graduate            No
# 10   LP001024    Male     Yes          2      Graduate            No
# 12   LP001028    Male     Yes          2      Graduate            No
# 13   LP001029    Male      No          0      Graduate            No
# 14   LP001030    Male     Yes          2      Graduate            No
# ...

# %%
Employed= pd.get_dummies(Train_loan_df['Self_Employed'], drop_first=True)

# %%
Employed
# Out:
#      Yes
# 1      0
# 2      1
# 3      0
# 4      0
# 5      1
# 6      0
# 7      0
# 8      0
# 9      0
# 10     0
# 12     0
# 13     0
# 14     0
# 15     0
# 17     0
# 18     0
# 20     0
# 21     0
# 22     0
# 25     1
# 26     0
# 27     0
# 28     0
# 31     0
# 32     1
# 33     0
# 34     0
# 37     0
# 38     0
# 39     0
# ..   ...
# 575    0
# 577    0
# 578    0
# 580    0
# 581    0
# 582    0
# 584    0
# 585    0
# 586    0
# 587    0
# 589    1
# 590    0
# 591    1
# 593    0
# 594    1
# 595    0
# 596    1
# 598    1
# 599    0
# 602    0
# 603    0
# 604    0
# 606    0
# 607    0
# 608    0
# 609    0
# 610    0
# 611    0
# 612    0
# 613    1
#
# [480 rows x 1 columns]

# %%
property_area= pd.get_dummies(Train_loan_df['Property_Area'], drop_first=True)

# %%
property_area
# Out:
#      Semiurban  Urban
# 1            0      0
# 2            0      1
# 3            0      1
# 4            0      1
# 5            0      1
# 6            0      1
# 7            1      0
# 8            0      1
# 9            1      0
# 10           0      1
# 12           0      1
# 13           0      0
# 14           0      1
# 15           0      1
# 17           0      1
# 18           0      0
# 20           0      1
# 21           0      1
# 22           1      0
# 25           1      0
# 26           1      0
# 27           0      1
# 28           0      1
# 31           0      1
# 32           0      0
# 33           1      0
# 34           0      0
# 37           1      0
# 38           0      1
# 39           1      0
# ..         ...    ...
# 575          0      1
# 577          0      1
# 578          0      0
# 580          1      0
# 581          0      1
# 582          1      0
# 584          0      0
# 585          0      0
# 586          0      1
# ...

# %%
graduate = pd.get_dummies(Train_loan_df['Education'], drop_first=True)

# %%
graduate
# Out:
#      Not Graduate
# 1               0
# 2               0
# 3               1
# 4               0
# 5               0
# 6               1
# 7               0
# 8               0
# 9               0
# 10              0
# 12              0
# 13              0
# 14              0
# 15              0
# 17              0
# 18              1
# 20              1
# 21              0
# 22              1
# 25              0
# 26              0
# 27              1
# 28              1
# 31              0
# 32              0
# 33              0
# 34              0
# 37              0
# 38              0
# 39              1
# ..            ...
# 575             0
# 577             0
# 578             0
# 580             0
# 581             0
# 582             0
# 584             0
# 585             0
# 586             0
# 587             1
# 589             0
# 590             0
# 591             0
# 593             0
# 594             0
# 595             1
# 596             1
# 598             0
# ...

# %%
Train_loan_df= pd.concat([Train_loan_df,graduate, property_area, Employed], axis=1)

# %%
# Converting Column name'Yes' to 'Employed'

# %%
Train_loan_df['Employed']= Train_loan_df['Yes']

# %%
Train_loan_df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 5    LP001011    Male     Yes          2      Graduate           Yes
# 6    LP001013    Male     Yes          0  Not Graduate            No
# 7    LP001014    Male     Yes         3+      Graduate            No
# 8    LP001018    Male     Yes          2      Graduate            No
# 9    LP001020    Male     Yes          1      Graduate            No
# 10   LP001024    Male     Yes          2      Graduate            No
# 12   LP001028    Male     Yes          2      Graduate            No
# 13   LP001029    Male      No          0      Graduate            No
# 14   LP001030    Male     Yes          2      Graduate            No
# ...

# %%
# Creating Dummies for "Loan Status", which is our prediction colummn

# %%
Train_loan_df.drop('Yes', axis=1, inplace=True)

# %%
Train_loan_df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 5    LP001011    Male     Yes          2      Graduate           Yes
# 6    LP001013    Male     Yes          0  Not Graduate            No
# 7    LP001014    Male     Yes         3+      Graduate            No
# 8    LP001018    Male     Yes          2      Graduate            No
# 9    LP001020    Male     Yes          1      Graduate            No
# 10   LP001024    Male     Yes          2      Graduate            No
# 12   LP001028    Male     Yes          2      Graduate            No
# 13   LP001029    Male      No          0      Graduate            No
# 14   LP001030    Male     Yes          2      Graduate            No
# ...

# %%
Approved=pd.get_dummies(Train_loan_df['Loan_Status'], drop_first=True)

# %%
Approved
# Out:
#      Y
# 1    0
# 2    1
# 3    1
# 4    1
# 5    1
# 6    1
# 7    0
# 8    1
# 9    0
# 10   1
# 12   1
# 13   0
# 14   1
# 15   1
# 17   0
# 18   0
# 20   0
# 21   1
# 22   0
# 25   1
# 26   1
# 27   1
# 28   0
# 31   0
# 32   0
# 33   1
# 34   0
# 37   1
# 38   1
# 39   1
# ..  ..
# 575  1
# 577  1
# 578  1
# 580  1
# 581  0
# 582  1
# 584  0
# 585  0
# 586  1
# 587  1
# 589  0
# 590  1
# 591  0
# 593  1
# 594  1
# 595  1
# 596  0
# 598  1
# 599  1
# 602  1
# 603  1
# 604  1
# 606  1
# 607  1
# 608  1
# 609  1
# 610  1
# 611  1
# 612  1
# 613  0
#
# [480 rows x 1 columns]

# %%
Train_loan_df=pd.concat([Train_loan_df, Approved], axis=1)

# %%
#need to delet the Duplicate column "Y"

# %%
Train_loan_df.columns.duplicated()
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False])

# %%
Train_loan_df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 5    LP001011    Male     Yes          2      Graduate           Yes
# 6    LP001013    Male     Yes          0  Not Graduate            No
# 7    LP001014    Male     Yes         3+      Graduate            No
# 8    LP001018    Male     Yes          2      Graduate            No
# 9    LP001020    Male     Yes          1      Graduate            No
# 10   LP001024    Male     Yes          2      Graduate            No
# 12   LP001028    Male     Yes          2      Graduate            No
# 13   LP001029    Male      No          0      Graduate            No
# 14   LP001030    Male     Yes          2      Graduate            No
# ...

# %%
Train_loan_df = Train_loan_df.iloc[:, ~Train_loan_df.columns.duplicated()]

# %%
Train_loan_df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 5    LP001011    Male     Yes          2      Graduate           Yes
# 6    LP001013    Male     Yes          0  Not Graduate            No
# 7    LP001014    Male     Yes         3+      Graduate            No
# 8    LP001018    Male     Yes          2      Graduate            No
# 9    LP001020    Male     Yes          1      Graduate            No
# 10   LP001024    Male     Yes          2      Graduate            No
# 12   LP001028    Male     Yes          2      Graduate            No
# 13   LP001029    Male      No          0      Graduate            No
# 14   LP001030    Male     Yes          2      Graduate            No
# ...

# %%
Train_loan_df.drop('Loan_Status', axis=1)
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 5    LP001011    Male     Yes          2      Graduate           Yes
# 6    LP001013    Male     Yes          0  Not Graduate            No
# 7    LP001014    Male     Yes         3+      Graduate            No
# 8    LP001018    Male     Yes          2      Graduate            No
# 9    LP001020    Male     Yes          1      Graduate            No
# 10   LP001024    Male     Yes          2      Graduate            No
# 12   LP001028    Male     Yes          2      Graduate            No
# 13   LP001029    Male      No          0      Graduate            No
# 14   LP001030    Male     Yes          2      Graduate            No
# ...

# %%
# Rename Column 'Y' to Loan_Approved

# %%
Train_loan_df.rename(columns= {'Y': 'Loan_Approved'})
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 5    LP001011    Male     Yes          2      Graduate           Yes
# 6    LP001013    Male     Yes          0  Not Graduate            No
# 7    LP001014    Male     Yes         3+      Graduate            No
# 8    LP001018    Male     Yes          2      Graduate            No
# 9    LP001020    Male     Yes          1      Graduate            No
# 10   LP001024    Male     Yes          2      Graduate            No
# 12   LP001028    Male     Yes          2      Graduate            No
# 13   LP001029    Male      No          0      Graduate            No
# 14   LP001030    Male     Yes          2      Graduate            No
# ...

# %%
Train_loan_df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 5    LP001011    Male     Yes          2      Graduate           Yes
# 6    LP001013    Male     Yes          0  Not Graduate            No
# 7    LP001014    Male     Yes         3+      Graduate            No
# 8    LP001018    Male     Yes          2      Graduate            No
# 9    LP001020    Male     Yes          1      Graduate            No
# 10   LP001024    Male     Yes          2      Graduate            No
# 12   LP001028    Male     Yes          2      Graduate            No
# 13   LP001029    Male      No          0      Graduate            No
# 14   LP001030    Male     Yes          2      Graduate            No
# ...

# %%
Train_loan_df.drop('Dependents', axis=1)
# Out:
#       Loan_ID  Gender Married     Education Self_Employed  ApplicantIncome  \
# 1    LP001003    Male     Yes      Graduate            No             4583
# 2    LP001005    Male     Yes      Graduate           Yes             3000
# 3    LP001006    Male     Yes  Not Graduate            No             2583
# 4    LP001008    Male      No      Graduate            No             6000
# 5    LP001011    Male     Yes      Graduate           Yes             5417
# 6    LP001013    Male     Yes  Not Graduate            No             2333
# 7    LP001014    Male     Yes      Graduate            No             3036
# 8    LP001018    Male     Yes      Graduate            No             4006
# 9    LP001020    Male     Yes      Graduate            No            12841
# 10   LP001024    Male     Yes      Graduate            No             3200
# 12   LP001028    Male     Yes      Graduate            No             3073
# ...

# %%
Train_loan_df.drop('Loan_Status', axis=1, inplace=True)

# %%
Train_loan_df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 5    LP001011    Male     Yes          2      Graduate           Yes
# 6    LP001013    Male     Yes          0  Not Graduate            No
# 7    LP001014    Male     Yes         3+      Graduate            No
# 8    LP001018    Male     Yes          2      Graduate            No
# 9    LP001020    Male     Yes          1      Graduate            No
# 10   LP001024    Male     Yes          2      Graduate            No
# 12   LP001028    Male     Yes          2      Graduate            No
# 13   LP001029    Male      No          0      Graduate            No
# 14   LP001030    Male     Yes          2      Graduate            No
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X= Train_loan_df.drop('Loan_Approved', axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-71-02b133d22988> in <module>
# ----> 1 X= Train_loan_df.drop('Loan_Approved', axis=1)
#
# E:\anaconda\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
#    3699     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# E:\anaconda\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3109         for axis, labels in axes.items():
#    3110             if labels is not None:
# ...

# %%
y= Train_loan_df['Loan_Approved']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# E:\anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Loan_Approved'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-72-6a7d42efb0ae> in <module>
# ----> 1 y= Train_loan_df['Loan_Approved']
#
# ...

# %%
X_train, X_test, y_train, y_test=train_test_split(X,y, test_size=0.3, random_state=42)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-73-b2da6d29f2e0> in <module>
# ----> 1 X_train, X_test, y_train, y_test=train_test_split(X,y, test_size=0.3, random_state=42)
#
# NameError: name 'X' is not defined

# %%
from sklearn.linear_model import LogisticRegression

# %%
log_model= LogisticRegression()

# %%
log_model.fit(X_train, y_train)

# %%
prediction = log_model.predict(X_test)

# %%
from sklearn.metrics import classification_report

# %%
classification_report(y_test, prediction)

# %%
# We can use confusion metrics for precision accuracy

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test, prediction)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-76-1733ff72e13c> in <module>
# ----> 1 confusion_matrix(y_test, prediction)
#
# NameError: name 'y_test' is not defined

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test, prediction)
